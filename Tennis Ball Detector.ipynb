# %%
import matplotlib.pyplot as plt
import numpy as np 
import math as math 

#import data set 

file_trial1 = open('TennisBallDetector1Ball.txt','r') 
content1=file_trial1.read()
trial1Data=map(int,content1.split())  
#print trial1Data
file_trial1.close 

file_trial2 = open('TennisBallDetector2Ball.txt','r') 
content1=file_trial2.read()
trial2Data=map(int,content1.split())  
#print trial2Data
file_trial2.close 

file_trial3 = open('TennisBallDetector3Ball.txt','r') 
content1=file_trial3.read()
trial3Data=map(int,content1.split())  
#print trial3Data
file_trial3.close 

file_trial4 = open('TennisBallDetector4Ball.txt','r') 
content1=file_trial4.read()
trial4Data=map(int,content1.split())  
#print trial4Data
file_trial4.close 

file_trial5 = open('TennisBallDetector5Ball.txt','r') 
content1=file_trial5.read()
trial5Data=map(int,content1.split())  
#print trial5Data
file_trial5.close 

file_trial6 = open('TennisBallDetector6Ball.txt','r') 
content1=file_trial6.read()
trial6Data=map(int,content1.split())  
#print trial6Data
file_trial6.close 

file_trial7 = open('TennisBallDetector7Ball.txt','r') 
content1=file_trial7.read()
trial7Data=map(int,content1.split())  
#print trial7Data
file_trial7.close
# Out:
# <function close>

# %%
#Plot Data for Each Trial

plt.hist(trial1Data, bins=15, color='orange') 
plt.xlabel('Number of Tennis Balls Detected', size=15)
plt.ylabel('Number of Throws', size=15)
plt.show() 

plt.hist(trial2Data, bins=15, color='orange') 
plt.xlabel('Number of Tennis Balls Detected', size=15)
plt.ylabel('Number of Throws', size=15)
plt.show() 

plt.hist(trial3Data, bins=20, color='orange') 
plt.xlabel('Number of Tennis Balls Detected', size=15)
plt.ylabel('Number of Throws', size=15)
plt.show() 

plt.hist(trial4Data, bins=20, color='orange') 
plt.xlabel('Number of Tennis Balls Detected', size=15)
plt.ylabel('Number of Throws', size=15)
plt.show() 

plt.hist(trial5Data, bins=20, color='orange') 
plt.xlabel('Number of Tennis Balls Detected', size=15)
plt.ylabel('Number of Throws', size=15)
plt.show() 

ax1=plt.subplot()
plt.hist(trial6Data, bins=20, color='orange') 
plt.xlabel('Number of Tennis Balls Detected', size=15)
plt.ylabel('Number of Throws', size=15)
ax1.set_xlim([0, 6])
plt.show() 

ax2=plt.subplot()
plt.hist(trial7Data, bins=20, color='orange') 
plt.xlabel('Number of Tennis Balls Detected', size=15)
plt.ylabel('Number of Throws', size=15) 
ax2.set_xlim([0, 7])
plt.show()
